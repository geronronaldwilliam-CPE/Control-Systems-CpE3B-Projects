# %%
import control as ctrl
import matplotlib.pyplot as plt

# Define transfer function G(s) = 1 / (s^2 + 2s + 1)
num = [1]          # numerator coefficients (constant 1)
den = [1, 2, 1]    # denominator coefficients (s^2 + 2s + 1)
G = ctrl.tf(num, den)   # create transfer function object
print(G)                # display transfer function
# Out:
# <TransferFunction>: sys[1]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#         1
#   -------------
#   s^2 + 2 s + 1

# %%
# Compute and display poles of G(s)
poles = ctrl.poles(G)
print("Poles: ", poles)
# Out:
# Poles:  [-1.+0.j -1.+0.j]

# %%
# Compute and display zeros of G(s)
zero = ctrl.zeros(G)
print("Zero: ", zero)
# Out:
# Zero:  []

# %%
# Plot pole-zero map with grid
import matplotlib.pyplot as plt

ctrl.pzmap(G, grid = True)
plt.show()
